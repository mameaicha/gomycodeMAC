# %% [markdown]
# # Categorize The Entities Into Different Types, Such As Names, Organizations, Locations, Dates, And So On.

# %%
#pip install ocr-nanonets-wrapper
#pip install python-docx

# %%
import spacy
from spacy.matcher import Matcher
import os
import docx
import sys
nlp = spacy.load('en_core_web_sm')

from nanonets import NANONETSOCR

# %%
#extract_text_from_pdf: This function takes a PDF or  file path as input and extracts text from all the pages in the PDF using NANONETSOCR

def extract_text_from_pdf_or_image(pdf_path):
    model = NANONETSOCR()
    model.set_token('87dcd5e7-53e9-11ee-bb5e-c26e11187d6d')
    text = model.convert_to_string(pdf_path,formatting='lines')
    text = text.strip()
    text = ' '.join(text.split())
    return text


#extract_text_from_docx: This function takes a DOCX file path as input and extracts text from the document using the docx library.
def extract_text_from_docx(docx_path):
    doc = docx.Document(docx_path)
    text = '\n'.join([para.text for para in doc.paragraphs])
    text = text.strip()
    text = ' '.join(text.split())
    return text

# %%
#Use spaCy to parse the resume and perform NER to identify named entities.
def parse_resume(resume_text):
    # Parse the resume text using spaCy
    doc = nlp(resume_text)

    # Extract named entities
    named_entities = [(ent.text, ent.label_) for ent in doc.ents]

    return named_entities

# %%
#categorize the entities into different types (e.g., names, organizations, locations, dates), you can filter the named entities based on their entity types
def categorize_entities(named_entities):
    entity_categories = {
        'person': [],
        'organization': [],
        'location': [],
        'date': [],
        'other': []
    }
    
    for entity, entity_type in named_entities:
        if entity_type == 'PERSON':
            entity_categories['person'].append(entity)
        elif entity_type == 'ORG':
            entity_categories['organization'].append(entity)
        elif entity_type == 'LOC':
            entity_categories['location'].append(entity)
        elif entity_type == 'DATE':
            entity_categories['date'].append(entity)
        else:
            entity_categories['other'].append(entity)
    
    return entity_categories

# %%
if __name__ == '__main__':
    # Directory containing candidate resumes (PDF, DOCX, and images)
    directory = 'C:/Users/user/Documents/GOMYCODE/ResumeParsing/dataset'
    Allcat_entities=[]
    #resume_paths = [r"C:/Users/user/Documents/GOMYCODE/ResumeParsing/dataset/3.pdf"]
    #file_path =os.listdir(directory)
    #for filename in file_path:
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)        
        if os.path.isfile(file_path) and (file_path.lower().endswith('.pdf') or file_path.lower().endswith('.png') or file_path.lower().endswith('.jpg'))  :
            #resume_text = extract_text_from_pdf(file_path)
            resume_text=extract_text_from_pdf_or_image(file_path)
            # Parse the resume and extract named entities
            named_entities = parse_resume(resume_text)
            # Categorize the named entities into types
            categorized_entities = categorize_entities(named_entities)
            Allcat_entities.append(categorized_entities)
        elif os.path.isfile(file_path) and file_path.lower().endswith('.docx'):
            resume_text = extract_text_from_docx(file_path)
            # Parse the resume and extract named entities
            named_entities = parse_resume(resume_text)
            # Categorize the named entities into types
            categorized_entities = categorize_entities(named_entities)
            Allcat_entities.append(categorized_entities)  
        else:
            print('Unsupported File Format:', filename)
        continue
# Out:
# Unsupported File Format: 25.jfif
# Unsupported File Format: 26.jfif
# Unsupported File Format: 28.jpeg
# Unsupported File Format: 29.jfif

# %%
Allcat_entities[0]
# Out:
# {'person': ['Avishek Kumar',
#   'Githul',
#   'AirAsia Digital',
#   'Scikit Pandas Numpy',
#   'Teknologi PETRONAS',
#   'Machine Learning Fluid Dynamics',
#   'Petronas',
#   'Link'],
#  'organization': ['Data Scientist\nMachine Learning',
#   'GN India',
#   'Data Scientist',
#   'EDA',
#   'Thesis Physics Informed Deep Learning',
#   'CNN',
#   'Contributed',
#   'AI/ML',
#   'Machine Data',
#   'Processing Statistical',
#   'KP',
#   'Keras Pytorch NLTK Spacy CLIPBOARD Research Projects',
#   'CNN',
#   'GMM PCA Transformer',
#   'Al',
#   'GCP',
#   'Masters Andhra University',
#   'Petroleum Engineering India',
#   'Bachelors University',
#   'Ph.D. of Petroleum & Energy Studies\nSecured',
#   'K',
#   'Petroleum Engineering India',
#   'Applied Mathematics'],
#  'location': [],
#  'date': ['years', '2016 - 2018', '2018 - 2023', '2013 2015', '2009'],
#  'other': ['+91999900011 05/22',
#   'Malaysia',
#   'more than 20%',
#   '87%',
#   '1',
#   'PhD',
#   'more than 90%',
# ...

# %%
resume_text1=extract_text_from_pdf_or_image("C:/Users/user/Documents/GOMYCODE/ResumeParsing/dataset/7.pdf")
resume_text2=extract_text_from_pdf_or_image("C:/Users/user/Documents/GOMYCODE/ResumeParsing/dataset/24.png")
resume_text3 = extract_text_from_docx("C:/Users/user/Documents/GOMYCODE/ResumeParsing/dataset/21.docx") 
resume_text4 = extract_text_from_docx("C:/Users/user/Documents/GOMYCODE/ResumeParsing/Resumes/Abiral_Pandey_Fullstack_Java.docx")

# %%
#Visualizing the entity recognizer

# %%
from spacy import displacy
nlp = spacy.load("en_core_web_sm")
doc = nlp(resume_text1)
displacy.serve(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">PAGE
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  KANOJA KUMAR MISHRA +91
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7978471213
# ...

# %%
named_entities1 = parse_resume(resume_text1)

# %%
named_entities1
# Out:
# [('1', 'CARDINAL'),
#  ('7978471213', 'CARDINAL'),
#  ('7', 'CARDINAL'),
#  ('3+', 'DATE'),
#  ('Skills Database Management My SQL Tableau', 'ORG'),
#  ('Pandas', 'PERSON'),
#  ('Matplotlib', 'PERSON'),
#  ('4', 'CARDINAL'),
#  ('Seaborn Boto3', 'PRODUCT'),
#  ('7', 'CARDINAL'),
#  ('EDA VBA', 'ORG'),
#  ('AI/ML NLP Regression', 'ORG'),
#  ('ROC', 'GPE'),
#  ('Naive Byes', 'PERSON'),
#  ('Linear Regression Random Forest', 'ORG'),
#  ('RDS Services', 'ORG'),
#  ('Lambda Function', 'ORG'),
#  ('Amazon layer Primary & Secondary Rescarch', 'ORG'),
#  ('Math s', 'PERSON'),
#  ('Statistics I MS Office', 'ORG'),
#  ('MS Excel', 'ORG'),
#  ('2021 2022', 'DATE'),
#  ('Tableau', 'GPE'),
#  ('SAAS', 'PERSON'),
#  ('Dashboard', 'PERSON'),
#  ('Analyzed', 'ORG'),
#  ('Performed EDA', 'ORG'),
#  ('VBA', 'ORG'),
#  ('NumPy Pandas', 'PERSON'),
#  ('Matplotlib', 'PERSON'),
#  ('Seaborne', 'PERSON'),
#  ('Sklearn', 'NORP'),
#  ('MySql', 'ORG'),
#  ('Optimization', 'PERSON'),
#  ('Data', 'ORG'),
# ...

# %% [markdown]
# Nous constatons qu'il ya des erreur de cathegorisation.
#
# C'est la raison pour laquelle nous devons d'abord entraîner notre modèle spacy sur des données étiquetées manuellement et créer un NER personnalisé.
#
# nous devons donc d'abord entraîner notre modèle spacy sur des données de CV étiquetées manuellement. Pour l'entraînement, nous avons obtenu des données en ligne
#
# Pour ameliorer cela, nous devons mettre à jour et former le NER en fonction du contexte et des exigences.
# Pour ce faire nous devons:
# - utiliser un modèle spacy pré-entraîné.
# - fournir des exemples d'entraînement qui permettront au NER d'apprendre pour les échantillons futurs.

# %% [markdown]
# # Training custom NER models using labeled data

# %% [markdown]
# ### Download the Training Data for bulding model

# %% [markdown]
# Nous avons telecharger des données de
#
# #https://www.kaggle.com/code/mohamedtaha7/ner-on-resumes-using-spacy/input?select=Entity+Recognition+in+Resumes.json

# %%
# import logging
import json
import re

# JSON formatting functions
def convert_dataturks_to_spacy(dataturks_JSON_FilePath):
    training_data = []
    lines=[]
    with open(dataturks_JSON_FilePath, encoding="utf8") as f:
        lines = f.readlines()

    for line in lines:
        data = json.loads(line)
        text = data['content'].replace("\n", " ")
        entities = []
        data_annotations = data['annotation']
        if data_annotations is not None:
            for annotation in data_annotations:
                #only a single point in text annotation.
                point = annotation['points'][0]
                labels = annotation['label']
                # handle both list of labels or a single label.
                if not isinstance(labels, list):
                    labels = [labels]

                for label in labels:
                    point_start = point['start']
                    point_end = point['end']
                    point_text = point['text']

                    lstrip_diff = len(point_text) - len(point_text.lstrip())
                    rstrip_diff = len(point_text) - len(point_text.rstrip())
                    if lstrip_diff != 0:
                        point_start = point_start + lstrip_diff
                    if rstrip_diff != 0:
                        point_end = point_end - rstrip_diff
                    entities.append((point_start, point_end + 1 , label))
        training_data.append((text, {"entities" : entities}))
    return training_data

def trim_entity_spans(data: list) -> list:
    
    invalid_span_tokens = re.compile(r'\s')

    cleaned_data = []
    for text, annotations in data:
        entities = annotations['entities']
        valid_entities = []
        for start, end, label in entities:
            valid_start = start
            valid_end = end
            while valid_start < len(text) and invalid_span_tokens.match(
                    text[valid_start]):
                valid_start += 1
            while valid_end > 1 and invalid_span_tokens.match(
                    text[valid_end - 1]):
                valid_end -= 1
            valid_entities.append([valid_start, valid_end, label])
        cleaned_data.append([text, {'entities': valid_entities}])
    return cleaned_data

# %%
data = trim_entity_spans(convert_dataturks_to_spacy("C:/Users/user/Documents/GOMYCODE/ResumeParsing/dataset/Entity Recognition in Resumes.json"))

# %%
data[0]
# Out:
# ["Abhishek Jha Application Development Associate - Accenture  Bengaluru, Karnataka - Email me on Indeed: indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a  • To work for an organization which provides me the opportunity to improve my skills and knowledge for my individual and company's growth in best possible ways.  Willing to relocate to: Bangalore, Karnataka  WORK EXPERIENCE  Application Development Associate  Accenture -  November 2017 to Present  Role: Currently working on Chat-bot. Developing Backend Oracle PeopleSoft Queries for the Bot which will be triggered based on given input. Also, Training the bot for different possible utterances (Both positive and negative), which will be given as input by the user.  EDUCATION  B.E in Information science and engineering  B.v.b college of engineering and technology -  Hubli, Karnataka  August 2013 to June 2017  12th in Mathematics  Woodbine modern school  April 2011 to March 2013  10th  Kendriya Vidyalaya  April 2001 to March 2011  SKILLS  C (
# ...

# %% [markdown]
# ### Modeling
# Train Test Split

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(data, test_size=0.2,random_state = 42)

len(train),len(test)
# Out:
# (176, 44)

# %%
### Conversion of Data to .spacy format

from spacy.tokens import DocBin
from tqdm import tqdm

def get_spacy_doc(file, data):
    # loading blank spacy model as we want to customize our model.
    # spacy.blank('en') will create a blank model of a given language class i.e., for here English.
    nlp = spacy.blank('en')
    db = DocBin()


    for text, annot in tqdm(data):
        doc = nlp.make_doc(text)
        annot = annot['entities']

        ents = []
        entity_indices = []

        for start, end, label in annot:
            skip_entity = False
            for idx in range(start, end):
                if idx in entity_indices:
                    skip_entity = True
                    break
            if skip_entity == True:
                continue

            entity_indices = entity_indices + list(range(start, end))

            try:
                span = doc.char_span(start, end,label=label,alignment_mode = 'strict')
            except:
                continue

            if span is None:
                err_data = str([start, end]) + " " + str(text) + "\n "
                file.write(err_data)
            else:
                ents.append(span)

        try:
            doc.ents = ents
            db.add(doc)
        except:
            pass
    return db

# %%
file = open('C:/Users/user/Documents/GOMYCODE/ResumeParsing/error.txt','w',encoding="utf-8")

db = get_spacy_doc(file, train)
db.to_disk('C:/Users/user/Documents/GOMYCODE/ResumeParsing/dataset/train_data.spacy')

db = get_spacy_doc(file, test)
db.to_disk('C:/Users/user/Documents/GOMYCODE/ResumeParsing/dataset/test_data.spacy')

file.close()
# Out:
# ...
# 100%|██████████| 44/44 [00:01<00:00, 33.56it/s]

# %%
# python -m spacy init fill-config C:/Users/user/Documents/GOMYCODE/ResumeParsing/base_config.cfg config.cfg

# %% [markdown]
# Training SpaCy

# %%
#!python -m spacy train C:/Users/user/Documents/GOMYCODE/ResumeParsing/config.cfg --output ./output --paths.train C:/Users/user/Documents/GOMYCODE/ResumeParsing/dataset/train_data.spacy --paths.dev C:/Users/user/Documents/GOMYCODE/ResumeParsing/dataset/test_data.spacy

# %%
nlp_ner = spacy.load('C:/Users/user/Documents/GOMYCODE/ResumeParsing/output/model-best')

# %%
def print_entities(text):
    doc = nlp_ner(text)
    for ent in doc.ents:
        print(ent.label_.upper(),"  =>  ", ent.text)

# %%
print_entities(resume_text1)
# Out:
# COLLEGE NAME   =>   Maharaia Engineering College Berhampur

# %%
print_entities(resume_text2)
# Out:
# NAME   =>   Diana Dawa
# SKILLS   =>   Data Scientist Data Visualization Machine Learning Deep Learning Future Energy Ltd
# COMPANIES WORKED AT   =>   Microsoft

# %%
print_entities(resume_text3)
# Out:
# NAME   =>   ASJIhina Mahajan

# %%
print_entities(resume_text4)
# Out:
# YEARS OF EXPERIENCE   =>   6 years
# DEGREE   =>   B. Strong experience in J2EE technologies like Java
# COMPANIES WORKED AT   =>   Oracle
# COMPANIES WORKED AT   =>   Relational
# COMPANIES WORKED AT   =>   Oracle
# DEGREE   =>   e-Commerce by using JSF framework and JavaScript, jQuery, HTML5
# DESIGNATION   =>   Java Developer November
# COMPANIES WORKED AT   =>   Oracle
# COMPANIES WORKED AT   =>   Oracle
# COMPANIES WORKED AT   =>   Oracle
# COMPANIES WORKED AT   =>   Oracle
# COMPANIES WORKED AT   =>   oracle
# COMPANIES WORKED AT   =>   Oracle
# COMPANIES WORKED AT   =>   Oracle

# %%
doc=nlp_ner(resume_text2) 
for e in doc.ents:
    print(f"spans: {(e.start, e.text, e.label_) }")
# Out:
# spans: (0, 'Diana Dawa', 'Name')
# spans: (90, 'Data Scientist Data Visualization Machine Learning Deep Learning Future Energy Ltd', 'Skills')
# spans: (297, 'Microsoft', 'Companies worked at')

# %% [markdown]
# "PERSON," "ORG," "GPE," and "PRODUCT"

# %% [markdown]
# # Phase IV
#
# Once The Entities Are Identified, The Relationships Between Them Are Extracted. For Example, The Relationship Between A Person's Name And SKILLS Can Be Extracted.

# %%
doc = nlp_ner(resume_text2)
#Extract Relationships:
relationships = []

for ent1 in doc.ents:
    for ent2 in doc.ents:
        if  ent1.label_.upper() == "NAME" and ent2.label_.upper() == "SKILLS" and ent1.start < ent2.start:
            relationships.append((ent1.text, ent2.text))

#Display the Relationships:
for relationship in relationships:
    print(f"{relationship[0]} is a {relationship[1]}")
# Out:
# Diana Dawa is a Data Scientist Data Visualization Machine Learning Deep Learning Future Energy Ltd
