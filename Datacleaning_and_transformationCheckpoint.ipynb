# %% [markdown]
# <a href="https://colab.research.google.com/github/mameaicha/gomycodeMAC/blob/main/Datacleaning_and_transformationCheckpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1: Data Exploration with Pandas

# %% [markdown]
# 1. Download the "covid_19_data.csv" file from the COVID-19 Dataset.

# %% [markdown]
# 2. Use pandas to read the file into a dataframe.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-3bde9f2a-3c14-4822-a335-a1fd919ee679" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3bde9f2a-3c14-4822-a335-a1fd919ee679">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("covid_19_data.csv")

# %% [markdown]
# 3. Use pandas to explore the dataset. For example, you might start by using the head() and info() methods to get an overview of the data.

# %%
# Combien de lignes comportent un data frame ? Et combien de colonnes ?
dim = df.shape
print ("Le dataset compte {} lignes et {} variables".format(dim[0], dim[1]))
# Out:
# Le dataset compte 306429 lignes et 8 variables

# %%
df.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
df.sample(10) #visualiser un echantillon aleatoire de 10 lignes sans remise
# Out:
#            SNo ObservationDate                Province/State Country/Region  \
# 196447  196448      01/06/2021                           NaN     Uzbekistan
# 214003  214004      01/29/2021                           NaN      Singapore
# 146177  146178      11/01/2020                           NaN          Libya
# 141961  141962      10/26/2020                         Idaho             US
# 181235  181236      12/17/2020  Australian Capital Territory      Australia
# 43023    43024      06/15/2020                         Delhi          India
# 284461  284462      05/01/2021                         Aysen          Chile
# 121592  121593      09/29/2020                Altai Republic         Russia
# 41149    41150      06/12/2020                         Shiga          Japan
# 245630  245631      03/11/2021             Kalmykia Republic         Russia
#
#                 Last Update  Confirmed  Deaths  Recovered
# 196447  2021-04-02 15:13:53    77350.0   615.0    75650.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306429 entries, 0 to 306428
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SNo              306429 non-null  int64
#  1   ObservationDate  306429 non-null  object
#  2   Province/State   228329 non-null  object
#  3   Country/Region   306429 non-null  object
#  4   Last Update      306429 non-null  object
#  5   Confirmed        306429 non-null  float64
#  6   Deaths           306429 non-null  float64
#  7   Recovered        306429 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 18.7+ MB

# %% [markdown]
# 4. Look for missing values in the dataset. You can use the isnull() method to identify missing values.

# %%
# pourcentage de valeurs manquante
(df.isnull().sum() / df.shape[0])*100
# Out:
# SNo                 0.000000
# ObservationDate     0.000000
# Province/State     25.487144
# Country/Region      0.000000
# Last Update         0.000000
# Confirmed           0.000000
# Deaths              0.000000
# Recovered           0.000000
# dtype: float64

# %% [markdown]
# Seule la variable **Province/State** a des valeurs manquantes de l'ordre de 25.5%

# %%
#df.dropna(axis=0, inplace=True)

# %% [markdown]
# 5. Use pandas to calculate some summary statistics for the dataset. For example, you might use the describe() method to get summary statistics for the numerical columns in the dataset.

# %%
df.describe() # fait un resumé statistique du dataset(variable quantitative par defaut)
# Out:
#                  SNo     Confirmed         Deaths     Recovered
# count  306429.000000  3.064290e+05  306429.000000  3.064290e+05
# mean   153215.000000  8.567091e+04    2036.403268  5.042029e+04
# std     88458.577156  2.775516e+05    6410.938048  2.015124e+05
# min         1.000000 -3.028440e+05    -178.000000 -8.544050e+05
# 25%     76608.000000  1.042000e+03      13.000000  1.100000e+01
# 50%    153215.000000  1.037500e+04     192.000000  1.751000e+03
# 75%    229822.000000  5.075200e+04    1322.000000  2.027000e+04
# max    306429.000000  5.863138e+06  112385.000000  6.399531e+06

# %% [markdown]
# Nous constatons que existance de valeurs abérantes(minimum négatives)

# %%
df[df["Confirmed"]<0]
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 147524  147525      11/02/2020        Unknown       Colombia
#
#                 Last Update  Confirmed  Deaths  Recovered
# 147524  2021-04-02 15:13:53  -302844.0     0.0        0.0

# %%
df[df["Deaths"]<0]
# Out:
# Empty DataFrame
# Columns: [SNo, ObservationDate, Province/State, Country/Region, Last Update, Confirmed, Deaths, Recovered]
# Index: []

# %%
df[df["Recovered"]<0]
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 118363  118364      09/24/2020        Unknown       Colombia
# 141534  141535      10/25/2020        Unknown       Colombia
# 145277  145278      10/30/2020        Unknown       Colombia
#
#                 Last Update  Confirmed  Deaths  Recovered
# 118363  2021-04-02 15:13:53        0.0  -178.0   -12684.0
# 141534  2021-04-02 15:13:53        0.0  -154.0    -8072.0
# 145277  2021-04-02 15:13:53        0.0   505.0  -854405.0

# %%
#supprimons les lignes contenant ces valeurs
#df.drop(df[df['Confirmed']<0 & df['Deaths']<0 & df['Recovered']<0].index, inplace=True)
df.drop(df[df['Confirmed']<0].index, inplace=True)

# %%
df.drop(df[df['Deaths']<0].index, inplace=True)

# %%
df.drop(df[df['Recovered']<0].index, inplace=True)

# %%
df.describe()
# Out:
#                  SNo     Confirmed         Deaths     Recovered
# count  306425.000000  3.064250e+05  306425.000000  3.064250e+05
# mean   153215.196322  8.567302e+04    2036.429286  5.042380e+04
# std     88459.127835  2.775524e+05    6410.975769  2.015071e+05
# min         1.000000  0.000000e+00       0.000000  0.000000e+00
# 25%     76607.000000  1.042000e+03      13.000000  1.100000e+01
# 50%    153217.000000  1.037600e+04     192.000000  1.751000e+03
# 75%    229823.000000  5.075200e+04    1322.000000  2.027000e+04
# max    306429.000000  5.863138e+06  112385.000000  6.399531e+06

# %%
var_num=df.select_dtypes(exclude="object").columns.to_list()
var_num
# Out:
# ['SNo', 'Confirmed', 'Deaths', 'Recovered']

# %%
#enleve SNo
var_num.remove('SNo')

# %%
import plotly.express as px # permet de creer des graph interactifs
for var in var_num :
  fig=px.box(df,x="Deaths",y=var,title=var+"vs Deaths ",color="Deaths")
  fig.show

# %% [markdown]
# # Part 2: Data Exploration with Pandas Profiling

# %% [markdown]
# 1. Use pandas profiling to explore the dataset. You can use the pandas_profiling.ProfileReport() method to create a report on the dataset.

# %%
# !pip install -U ydata-profiling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.9/345.9 kB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.7/33.7 MB 27.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 65.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 11.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 48.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 29.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 95.7 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=389b33921ba8f18562bbfd095f351dc28b1d5093fe8ee2a033f2fc45a3ef9d25
# ...

# %%
from ydata_profiling import ProfileReport

#from ydata_profiling.utils.cache import cache_file

# Download the "covid_19_data.csv" file from the COVID-19 Dataset.
# Read the Dataset

#file_name = cache_file(
#   "covid_19_data.csv",
#    "https://drive.google.com/u/0/uc?id=102nJy7BpCnKedsFNsib5VxQuF67uyqq3&export=download",)

#df = pd.read_csv(file_name)

# %%
# Generate the Profiling Report
profile = ProfileReport(
    df, title="covid_19 Dataset", html={"style": {"full_width": True}}, sort=None
)

# use the HTML report in an iframe
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.1.2&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-05-10 17:17:59.694139&quot;&gt;&lt;title&gt;covid_19 Dataset&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
# save html file
profile.to_file("/home/rapportcovid19.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# 2. Look for missing values in the dataset. You can use the report generated by pandas profiling to identify missing values.

# %% [markdown]
# seule la variables Province/State a des donnes manquantes. Elles representent 25.5% des observations.
#
# Nous envisageons de la supprimer etant données nous avons aussi une information sur le pays ou regions representé par la variable **Country/Region**

# %% [markdown]
# 3. Look for correlations between different columns in the dataset. You can use the report generated by pandas profiling to identify correlations between different columns.

# %% [markdown]
# il existe une forte correlation entre  les variables
# **Confirmed** et **Deaths** de meme entre **Recovered** et **Confirmed**

# %% [markdown]
# 4. Identify any outliers or unusual values in the dataset. You can use the report generated by pandas profiling to identify any outliers or unusual values.

# %% [markdown]
# # Summary
# At the end of this exercise, write a summary of your findings. What did you learn about the COVID-19 Dataset? Did you find any interesting patterns or correlations in the data? Were there any issues or challenges you encountered while exploring the dataset? Use your summary to reflect on your experience using pandas and pandas profiling to explore and understand a new dataset.

# %% [markdown]
# L'ensemble de données COVID-19 contient des informations sur les cas de COVID-19 et les décès dans différents pays.
# seule la variables **Province/State** a des données manquantes. Elles representent 25.5% des observations.
#
# Nous envisageons de la supprimer etant données nous avons aussi une information sur le pays ou regions representé par la variable **Country/Region**
#
# Il existe une forte correlation entre les variables Confirmed et Deaths de meme entre Recovered et Confirmed
